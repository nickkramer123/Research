# %%
import matplotlib.pyplot as plt

# %% [markdown]
# Import data for plots:

# %%
# import best_scores
best_scores = []
with open('best_scores50.txt', 'r') as file:
    for line in file:
        processed_line = line.strip()
        best_scores.append(float(processed_line))


# import best_chaos
best_chaos = []
with open('choas_scores50.txt', 'r') as file:
    for line in file:
        processed_line = line.strip()
        best_chaos.append(float(processed_line))

# %% [markdown]
# Make the b vs synergy with color plot:

# %%
# Create b values
b_values = [i * 0.002 for i in range(len(best_scores))]

# Plot with chaos as color
fig, ax = plt.subplots()
scatter = ax.scatter(b_values, best_scores, c=best_chaos, 
                     cmap='viridis', alpha=0.6, s=50)

ax.set_xlabel('b value')
ax.set_ylabel('best fitness')

# Add colorbar to show chaos scale
cbar = plt.colorbar(scatter, ax=ax)
cbar.set_label('Chaos Measure (Lyapunov)')

# plt.savefig("ChoasVsSynergy1.png")
plt.show()

# %% [markdown]
# Other plot

# %%
plt.scatter(best_scores, best_chaos)
plt.show()
